# %%
import matplotlib

# 设置Matplotlib支持中文字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']  # 指定默认字体
matplotlib.rcParams['axes.unicode_minus'] = False  # 解决保存图像是负号'-'显示为方块的问题

# %% [markdown]
# # 季节性ARIMA模型（SARIMAX）

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error

# 加载数据
data = pd.read_excel('第一问.xlsx')
data['日期'] = pd.to_datetime(data['日期'])
data.set_index('日期', inplace=True)
data = data.asfreq('D')  # 设置日期索引的频率

# 填充缺失数据
data.fillna(method='ffill', inplace=True)

# 定义训练和测试数据
train_data = data[:'2023-06-30']
test_data = data['2023-07-01':'2024-05-21']

# 构建季节性ARIMA模型，包含外生变量
exog_train = train_data[['门诊患者人次数', '药品总收入', '当日病房收入']]
exog_test = test_data[['门诊患者人次数', '药品总收入', '当日病房收入']]
model_sarima = SARIMAX(train_data['门诊收入OBS_T01_MZSR68'], order=(3, 1, 1), seasonal_order=(0, 0, 1, 12), exog=exog_train)
fitted_model_sarima = model_sarima.fit()

# 进行预测
forecast = fitted_model_sarima.predict(start='2023-07-01', end='2024-05-21', exog=exog_test, typ='levels')

# 计算均方误差
mse = mean_squared_error(test_data['门诊收入OBS_T01_MZSR68'].dropna(), forecast[test_data['门诊收入OBS_T01_MZSR68'].dropna().index])
print("均方误差 (MSE):", mse)

# 绘制原始数据与预测数据对比图，仅显示预测值
end_date = '2024-01-26'
plt.figure(figsize=(12, 6))
plt.plot(data['门诊收入OBS_T01_MZSR68'][:'2024-01-26'], label='原始门诊收入', color='lightgray')  # 显示原始数据但用淡色表示
plt.plot(forecast, color='red', label='季节性ARIMA预测', linestyle='--')  # 显示所有预测值
plt.title('门诊收入预测')
plt.xlabel('日期')
plt.ylabel('门诊收入')
plt.legend()
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_25052\3145909700.py:14: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
# 均方误差 (MSE): 9777363004.021603
# c:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning: Unknown keyword arguments: dict_keys(['typ']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.metrics import mean_squared_error, accuracy_score, f1_score, roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# 定义截止日期并按日期过滤数据
end_date = '2024-01-26'
filtered_test_data = test_data[:end_date]['门诊收入OBS_T01_MZSR68'].dropna()
filtered_forecast = forecast[:end_date]

# 定义分类标准：使用门诊收入的中位数作为分类阈值
threshold = data['门诊收入OBS_T01_MZSR68'].median()
test_data_binary = (filtered_test_data > threshold).astype(int)
forecast_binary = (filtered_forecast > threshold).astype(int)

# 计算分类指标
accuracy = accuracy_score(test_data_binary, forecast_binary)
f1 = f1_score(test_data_binary, forecast_binary)
print("准确率 (Accuracy):", accuracy)
print("F1-score:", f1)

# 绘制ROC曲线
fpr, tpr, _ = roc_curve(test_data_binary, filtered_forecast)
auc = roc_auc_score(test_data_binary, filtered_forecast)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC曲线 (AUC = {:.2f})'.format(auc))
plt.plot([0, 1], [0, 1], 'r--')
plt.xlabel('假阳性率')
plt.ylabel('真阳性率')
plt.title('ROC曲线')
plt.legend()
plt.show()
# Out:
# 准确率 (Accuracy): 0.8095238095238095
# F1-score: 0.875

# %% [markdown]
# # LSTM

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# 加载数据
data = pd.read_excel('第一问.xlsx')
data['日期'] = pd.to_datetime(data['日期'])
data.set_index('日期', inplace=True)

# 数据预处理
data.interpolate(method='time', inplace=True)  # 时间序列插值处理缺失值

# 选择特征和目标列
features = ['门诊患者人次数', '药品总收入', '当日病房收入']
target = ['门诊收入OBS_T01_MZSR68']

# 数据归一化
scaler_features = MinMaxScaler(feature_range=(0, 1))
scaler_target = MinMaxScaler(feature_range=(0, 1))
data_scaled_features = scaler_features.fit_transform(data[features])
data_scaled_target = scaler_target.fit_transform(data[target])
data_scaled = np.hstack((data_scaled_features, data_scaled_target))

# 创建时间序列数据集
def create_multivariate_dataset(dataset, look_back=10):
    X, Y = [], []
    for i in range(len(dataset) - look_back - 1):
        X.append(dataset[i:(i + look_back), :-1])  # 特征
        Y.append(dataset[i + look_back, -1])       # 目标
    return np.array(X), np.array(Y)

look_back = 10
X, Y = create_multivariate_dataset(data_scaled, look_back)

# 分割数据
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# 构建LSTM模型
model = Sequential()
model.add(LSTM(256, input_shape=(look_back, X.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64))
model.add(Dropout(0.2))
model.add(Dense(1))

optimizer = Adam(learning_rate=0.001)
model.compile(loss='mean_squared_error', optimizer=optimizer)

# 训练模型
model.fit(X_train, Y_train, epochs=100, batch_size=32, verbose=2, validation_split=0.1)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_25052\3721830842.py:15: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data.interpolate(method='time', inplace=True)  # 时间序列插值处理缺失值
# Epoch 1/100
# 3/3 - 3s - loss: 0.1000 - val_loss: 0.0666 - 3s/epoch - 1s/step
# Epoch 2/100
# 3/3 - 0s - loss: 0.0394 - val_loss: 0.0601 - 77ms/epoch - 26ms/step
# Epoch 3/100
# 3/3 - 0s - loss: 0.0362 - val_loss: 0.0635 - 76ms/epoch - 25ms/step
# Epoch 4/100
# 3/3 - 0s - loss: 0.0321 - val_loss: 0.0620 - 75ms/epoch - 25ms/step
# Epoch 5/100
# 3/3 - 0s - loss: 0.0300 - val_loss: 0.0553 - 77ms/epoch - 26ms/step
# Epoch 6/100
# 3/3 - 0s - loss: 0.0295 - val_loss: 0.0598 - 76ms/epoch - 25ms/step
# Epoch 7/100
# 3/3 - 0s - loss: 0.0258 - val_loss: 0.0640 - 76ms/epoch - 25ms/step
# Epoch 8/100
# 3/3 - 0s - loss: 0.0260 - val_loss: 0.0550 - 76ms/epoch - 25ms/step
# Epoch 9/100
# 3/3 - 0s - loss: 0.0281 - val_loss: 0.0565 - 77ms/epoch - 26ms/step
# Epoch 10/100
# 3/3 - 0s - loss: 0.0247 - val_loss: 0.0599 - 75ms/epoch - 25ms/step
# Epoch 11/100
# 3/3 - 0s - loss: 0.0228 - val_loss: 0.0566 - 76ms/epoch - 25ms/step
# Epoch 12/100
# 3/3 - 0s - loss: 0.0269 - val_loss: 0.0617 - 76ms/epoch - 25ms/step
# Epoch 13/100
# 3/3 - 0s - loss: 0.0227 - val_loss: 0.0673 - 77ms/epoch - 26ms/step
# Epoch 14/100
# 3/3 - 0s - loss: 0.0264 - val_loss: 0.0614 - 76ms/epoch - 25ms/step
# Epoch 15/100
# 3/3 - 0s - loss: 0.0245 - val_loss: 0.0646 - 74ms/epoch - 25ms/step
# Epoch 16/100
# 3/3 - 0s - loss: 0.0265 - val_loss: 0.0676 - 77ms/epoch - 26ms/step
# Epoch 17/100
# 3/3 - 0s - loss: 0.0244 - val_loss: 0.0571 - 75ms/epoch - 25ms/step
# Epoch 18/100
# 3/3 - 0s - loss: 0.0274 - val_loss: 0.0556 - 75ms/epoch - 25ms/step
# Epoch 19/100
# 3/3 - 0s - loss: 0.0216 - val_loss: 0.0607 - 76ms/epoch - 25ms/step
# Epoch 20/100
# 3/3 - 0s - loss: 0.0237 - val_loss: 0.0561 - 76ms/epoch - 25ms/step
# Epoch 21/100
# 3/3 - 0s - loss: 0.0215 - val_loss: 0.0557 - 80ms/epoch - 27ms/step
# Epoch 22/100
# 3/3 - 0s - loss: 0.0219 - val_loss: 0.0529 - 76ms/epoch - 25ms/step
# Epoch 23/100
# 3/3 - 0s - loss: 0.0315 - val_loss: 0.0541 - 75ms/epoch - 25ms/step
# Epoch 24/100
# 3/3 - 0s - loss: 0.0221 - val_loss: 0.0652 - 75ms/epoch - 25ms/step
# Epoch 25/100
# 3/3 - 0s - loss: 0.0262 - val_loss: 0.0596 - 75ms/epoch - 25ms/step
# Epoch 26/100
# 3/3 - 0s - loss: 0.0207 - val_loss: 0.0499 - 75ms/epoch - 25ms/step
# Epoch 27/100
# 3/3 - 0s - loss: 0.0240 - val_loss: 0.0497 - 76ms/epoch - 25ms/step
# Epoch 28/100
# 3/3 - 0s - loss: 0.0219 - val_loss: 0.0533 - 75ms/epoch - 25ms/step
# Epoch 29/100
# 3/3 - 0s - loss: 0.0239 - val_loss: 0.0510 - 75ms/epoch - 25ms/step
# Epoch 30/100
# 3/3 - 0s - loss: 0.0242 - val_loss: 0.0500 - 76ms/epoch - 25ms/step
# Epoch 31/100
# 3/3 - 0s - loss: 0.0247 - val_loss: 0.0510 - 76ms/epoch - 25ms/step
# Epoch 32/100
# 3/3 - 0s - loss: 0.0195 - val_loss: 0.0543 - 75ms/epoch - 25ms/step
# Epoch 33/100
# 3/3 - 0s - loss: 0.0223 - val_loss: 0.0526 - 76ms/epoch - 25ms/step
# Epoch 34/100
# 3/3 - 0s - loss: 0.0212 - val_loss: 0.0507 - 75ms/epoch - 25ms/step
# Epoch 35/100
# 3/3 - 0s - loss: 0.0218 - val_loss: 0.0530 - 75ms/epoch - 25ms/step
# Epoch 36/100
# 3/3 - 0s - loss: 0.0197 - val_loss: 0.0561 - 76ms/epoch - 25ms/step
# Epoch 37/100
# 3/3 - 0s - loss: 0.0179 - val_loss: 0.0543 - 75ms/epoch - 25ms/step
# Epoch 38/100
# 3/3 - 0s - loss: 0.0198 - val_loss: 0.0536 - 76ms/epoch - 25ms/step
# Epoch 39/100
# 3/3 - 0s - loss: 0.0218 - val_loss: 0.0529 - 75ms/epoch - 25ms/step
# Epoch 40/100
# 3/3 - 0s - loss: 0.0229 - val_loss: 0.0521 - 75ms/epoch - 25ms/step
# Epoch 41/100
# 3/3 - 0s - loss: 0.0225 - val_loss: 0.0512 - 76ms/epoch - 25ms/step
# Epoch 42/100
# 3/3 - 0s - loss: 0.0207 - val_loss: 0.0521 - 76ms/epoch - 25ms/step
# Epoch 43/100
# 3/3 - 0s - loss: 0.0195 - val_loss: 0.0509 - 75ms/epoch - 25ms/step
# Epoch 44/100
# 3/3 - 0s - loss: 0.0189 - val_loss: 0.0511 - 75ms/epoch - 25ms/step
# Epoch 45/100
# 3/3 - 0s - loss: 0.0197 - val_loss: 0.0491 - 74ms/epoch - 25ms/step
# Epoch 46/100
# 3/3 - 0s - loss: 0.0193 - val_loss: 0.0509 - 76ms/epoch - 25ms/step
# Epoch 47/100
# 3/3 - 0s - loss: 0.0195 - val_loss: 0.0507 - 76ms/epoch - 25ms/step
# Epoch 48/100
# 3/3 - 0s - loss: 0.0200 - val_loss: 0.0514 - 76ms/epoch - 25ms/step
# Epoch 49/100
# 3/3 - 0s - loss: 0.0172 - val_loss: 0.0515 - 76ms/epoch - 25ms/step
# Epoch 50/100
# 3/3 - 0s - loss: 0.0167 - val_loss: 0.0516 - 76ms/epoch - 25ms/step
# Epoch 51/100
# 3/3 - 0s - loss: 0.0159 - val_loss: 0.0583 - 76ms/epoch - 25ms/step
# Epoch 52/100
# 3/3 - 0s - loss: 0.0247 - val_loss: 0.0520 - 77ms/epoch - 26ms/step
# Epoch 53/100
# 3/3 - 0s - loss: 0.0176 - val_loss: 0.0524 - 76ms/epoch - 25ms/step
# Epoch 54/100
# 3/3 - 0s - loss: 0.0195 - val_loss: 0.0495 - 78ms/epoch - 26ms/step
# Epoch 55/100
# 3/3 - 0s - loss: 0.0182 - val_loss: 0.0493 - 76ms/epoch - 25ms/step
# Epoch 56/100
# 3/3 - 0s - loss: 0.0172 - val_loss: 0.0551 - 76ms/epoch - 25ms/step
# Epoch 57/100
# 3/3 - 0s - loss: 0.0220 - val_loss: 0.0495 - 75ms/epoch - 25ms/step
# Epoch 58/100
# 3/3 - 0s - loss: 0.0199 - val_loss: 0.0494 - 75ms/epoch - 25ms/step
# Epoch 59/100
# 3/3 - 0s - loss: 0.0205 - val_loss: 0.0514 - 76ms/epoch - 25ms/step
# Epoch 60/100
# 3/3 - 0s - loss: 0.0206 - val_loss: 0.0496 - 76ms/epoch - 25ms/step
# Epoch 61/100
# 3/3 - 0s - loss: 0.0203 - val_loss: 0.0517 - 74ms/epoch - 25ms/step
# Epoch 62/100
# 3/3 - 0s - loss: 0.0202 - val_loss: 0.0569 - 81ms/epoch - 27ms/step
# Epoch 63/100
# 3/3 - 0s - loss: 0.0200 - val_loss: 0.0516 - 74ms/epoch - 25ms/step
# Epoch 64/100
# 3/3 - 0s - loss: 0.0211 - val_loss: 0.0544 - 76ms/epoch - 25ms/step
# Epoch 65/100
# 3/3 - 0s - loss: 0.0199 - val_loss: 0.0508 - 78ms/epoch - 26ms/step
# Epoch 66/100
# 3/3 - 0s - loss: 0.0164 - val_loss: 0.0511 - 76ms/epoch - 25ms/step
# Epoch 67/100
# 3/3 - 0s - loss: 0.0192 - val_loss: 0.0478 - 75ms/epoch - 25ms/step
# Epoch 68/100
# 3/3 - 0s - loss: 0.0184 - val_loss: 0.0470 - 80ms/epoch - 27ms/step
# Epoch 69/100
# 3/3 - 0s - loss: 0.0195 - val_loss: 0.0470 - 77ms/epoch - 26ms/step
# Epoch 70/100
# 3/3 - 0s - loss: 0.0201 - val_loss: 0.0497 - 79ms/epoch - 26ms/step
# Epoch 71/100
# 3/3 - 0s - loss: 0.0198 - val_loss: 0.0530 - 75ms/epoch - 25ms/step
# Epoch 72/100
# 3/3 - 0s - loss: 0.0175 - val_loss: 0.0545 - 75ms/epoch - 25ms/step
# Epoch 73/100
# 3/3 - 0s - loss: 0.0186 - val_loss: 0.0593 - 76ms/epoch - 25ms/step
# Epoch 74/100
# 3/3 - 0s - loss: 0.0163 - val_loss: 0.0662 - 76ms/epoch - 25ms/step
# Epoch 75/100
# 3/3 - 0s - loss: 0.0198 - val_loss: 0.0558 - 74ms/epoch - 25ms/step
# Epoch 76/100
# 3/3 - 0s - loss: 0.0161 - val_loss: 0.0504 - 76ms/epoch - 25ms/step
# Epoch 77/100
# 3/3 - 0s - loss: 0.0240 - val_loss: 0.0441 - 76ms/epoch - 25ms/step
# Epoch 78/100
# 3/3 - 0s - loss: 0.0218 - val_loss: 0.0401 - 76ms/epoch - 25ms/step
# Epoch 79/100
# 3/3 - 0s - loss: 0.0209 - val_loss: 0.0442 - 80ms/epoch - 27ms/step
# Epoch 80/100
# 3/3 - 0s - loss: 0.0202 - val_loss: 0.0498 - 76ms/epoch - 25ms/step
# Epoch 81/100
# 3/3 - 0s - loss: 0.0169 - val_loss: 0.0530 - 79ms/epoch - 26ms/step
# Epoch 82/100
# 3/3 - 0s - loss: 0.0199 - val_loss: 0.0531 - 76ms/epoch - 25ms/step
# Epoch 83/100
# 3/3 - 0s - loss: 0.0191 - val_loss: 0.0499 - 78ms/epoch - 26ms/step
# Epoch 84/100
# 3/3 - 0s - loss: 0.0181 - val_loss: 0.0481 - 77ms/epoch - 26ms/step
# Epoch 85/100
# 3/3 - 0s - loss: 0.0178 - val_loss: 0.0456 - 77ms/epoch - 26ms/step
# Epoch 86/100
# 3/3 - 0s - loss: 0.0194 - val_loss: 0.0453 - 81ms/epoch - 27ms/step
# Epoch 87/100
# 3/3 - 0s - loss: 0.0156 - val_loss: 0.0473 - 77ms/epoch - 26ms/step
# Epoch 88/100
# 3/3 - 0s - loss: 0.0157 - val_loss: 0.0525 - 74ms/epoch - 25ms/step
# Epoch 89/100
# 3/3 - 0s - loss: 0.0175 - val_loss: 0.0580 - 77ms/epoch - 26ms/step
# Epoch 90/100
# 3/3 - 0s - loss: 0.0178 - val_loss: 0.0562 - 76ms/epoch - 25ms/step
# Epoch 91/100
# 3/3 - 0s - loss: 0.0166 - val_loss: 0.0506 - 75ms/epoch - 25ms/step
# Epoch 92/100
# 3/3 - 0s - loss: 0.0177 - val_loss: 0.0449 - 77ms/epoch - 26ms/step
# Epoch 93/100
# 3/3 - 0s - loss: 0.0152 - val_loss: 0.0426 - 75ms/epoch - 25ms/step
# Epoch 94/100
# 3/3 - 0s - loss: 0.0201 - val_loss: 0.0428 - 79ms/epoch - 26ms/step
# Epoch 95/100
# 3/3 - 0s - loss: 0.0168 - val_loss: 0.0437 - 76ms/epoch - 25ms/step
# Epoch 96/100
# 3/3 - 0s - loss: 0.0164 - val_loss: 0.0428 - 76ms/epoch - 25ms/step
# Epoch 97/100
# 3/3 - 0s - loss: 0.0172 - val_loss: 0.0439 - 74ms/epoch - 25ms/step
# Epoch 98/100
# 3/3 - 0s - loss: 0.0152 - val_loss: 0.0455 - 75ms/epoch - 25ms/step
# Epoch 99/100
# 3/3 - 0s - loss: 0.0160 - val_loss: 0.0457 - 78ms/epoch - 26ms/step
# Epoch 100/100
# 3/3 - 0s - loss: 0.0167 - val_loss: 0.0452 - 76ms/epoch - 25ms/step

# %%
import matplotlib.pyplot as plt

# 进行预测
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# 反归一化以获得实际的收入值
train_predict = scaler_target.inverse_transform(train_predict)
test_predict = scaler_target.inverse_transform(test_predict)
Y_train_actual = scaler_target.inverse_transform(Y_train.reshape(-1, 1))
Y_test_actual = scaler_target.inverse_transform(Y_test.reshape(-1, 1))

# 计算预测和实际之间的误差
train_error = Y_train_actual - train_predict
test_error = Y_test_actual - test_predict

# 绘制训练和测试的预测结果
plt.figure(figsize=(15, 6))
plt.subplot(121)
plt.plot(Y_train_actual, label='实际值')
plt.plot(train_predict, label='预测值')
plt.title('训练集预测')
plt.xlabel('时间')
plt.ylabel('门诊收入')
plt.legend()

plt.subplot(122)
plt.plot(Y_test_actual, label='实际值')
plt.plot(test_predict, label='预测值')
plt.title('测试集预测')
plt.xlabel('时间')
plt.ylabel('门诊收入')
plt.legend()
plt.show()

# 绘制误差分布图
plt.figure(figsize=(15, 6))
plt.subplot(121)
plt.hist(train_error, bins=30)
plt.title('训练集预测误差分布')
plt.xlabel('预测误差')
plt.ylabel('频率')

plt.subplot(122)
plt.hist(test_error, bins=30)
plt.title('测试集预测误差分布')
plt.xlabel('预测误差')
plt.ylabel('频率')
plt.show()
# Out:
# 3/3 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 3ms/step

# %%
# 预测
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# 反归一化预测结果
train_predict = scaler_target.inverse_transform(train_predict)
test_predict = scaler_target.inverse_transform(test_predict)
Y_train_actual = scaler_target.inverse_transform(Y_train.reshape(-1, 1))
Y_test_actual = scaler_target.inverse_transform(Y_test.reshape(-1, 1))

# 定义分类阈值
threshold = np.median(Y_test_actual)  # 可以调整这个阈值定义

# 创建二进制分类结果
test_data_binary = (Y_test_actual > threshold).astype(int)
forecast_binary = (test_predict > threshold).astype(int)

# 计算准确率和F1-score
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, roc_curve

accuracy = accuracy_score(test_data_binary, forecast_binary)
f1 = f1_score(test_data_binary, forecast_binary)
print("准确率 (Accuracy):", accuracy)
print("F1-score:", f1)

# 绘制ROC曲线
fpr, tpr, _ = roc_curve(test_data_binary, test_predict)
auc = roc_auc_score(test_data_binary, test_predict)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC曲线 (AUC = {:.2f})'.format(auc))
plt.plot([0, 1], [0, 1], 'r--')
plt.xlabel('假阳性率')
plt.ylabel('真阳性率')
plt.title('ROC曲线')
plt.legend()
plt.show()
# Out:
# 3/3 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 4ms/step
# 准确率 (Accuracy): 0.7
# F1-score: 0.6470588235294118
